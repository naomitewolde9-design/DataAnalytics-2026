# %% [markdown]
# # Exercise 2.A Fundamentals of pandas

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ## Series

# %%
# Plain Python objects
aa = [1, 2, 3, 4]
ab = (5, 6, 7, 8)
ac = {9, 10, 11, 12}
ad = {
    'first': 13,
    'second': 14,
    'third': 15,
    'fourth': 16
}

# %%
ser1 = pd.Series(aa)
ser2 = pd.Series(ab)
ser3 = pd.Series(sorted(ac))   
ser4 = pd.Series(ad)

# Print results
print("ser1:\n", ser1)
print("\nser2:\n", ser2)
print("\nser3:\n", ser3)
print("\nser4:\n", ser4)
# Out:
# ser1:
#  0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
#
# ser2:
#  0    5
# 1    6
# 2    7
# 3    8
# dtype: int64
#
# ser3:
#  0     9
# 1    10
# 2    11
# 3    12
# dtype: int64
#
# ser4:
#  first     13
# second    14
# third     15
# fourth    16
# dtype: int64

# %%
ser5 = pd.Series(17, 18, 19, 20)

# TypeError: 
# Series.__init__() takes from 1 to 4 positional arguments but 5 were given
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ser5 = pd.Series(17, 18, 19, 20)
#       3 # TypeError: Series.__init__() takes from 1 to 4 positional arguments but 5 were given
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:493, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     490 name = ibase.maybe_extract_name(name, data, type(self))
#     492 if index is not None:
# --> 493     index = ensure_index(index)
#     495 if dtype is not None:
#     496     dtype = self._validate_dtype(dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7715, in ensure_index(index_like, copy)
#    7713         return Index(index_like, copy=copy, tupleize_cols=False)
#    7714 else:
# -> 7715     return Index(index_like, copy=copy)
#
# ...

# %%
ser5 = pd.Series([17, 18, 19, 20])

# %%
print("\nser5:\n", ser5)
# Out:
# ser5:
#  0    17
# 1    18
# 2    19
# 3    20
# dtype: int64

# %% [markdown]
# ## DataFrames from Series

# %%
df1 = pd.DataFrame(ser1)

df1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df1.insert(1, "col2", ser2)
df1.insert(2, "col3", ser3)

df1
# Out:
#    0  col2  col3
# 0  1     5     9
# 1  2     6    10
# 2  3     7    11
# 3  4     8    12

# %%
df1.insert(3, "col4", ser4)

df1

# ser4 is different because it comes from a dictionary, which uses keys
# as its index instead of numeric values (0,1,2,3).
# When added to df1, pandas aligns data by index labels, causing mismatched
# indices to produce NaN values in the DataFrame.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4112\73695589.py in ?()
# ----> 1 df1.insert(3, "col4", ser4)
#       2
#       3 df1
#       4
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5176                 "'self.flags.allows_duplicate_labels' is False."
#    5177             )
#    5178         if not allow_duplicates and column in self.columns:
#    5179             # Should this be a different kind of error??
# -> 5180             raise ValueError(f"cannot insert {column}, already exists")
#    5181         if not is_integer(loc):
#    5182             raise TypeError("loc must be int")
#    5183         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert col4, already exists

# %%
# troubleshoot error 
df1["col4"] = ser4

df1
# Out:
#    0  col2  col3  col4
# 0  1     5     9   NaN
# 1  2     6    10   NaN
# 2  3     7    11   NaN
# 3  4     8    12   NaN
# 4  5     9    12   NaN

# %%
df1.loc[4] = [5, 9, 12, 0]

df1
# Out:
#    0  col2  col3  col4
# 0  1     5     9   NaN
# 1  2     6    10   NaN
# 2  3     7    11   NaN
# 3  4     8    12   NaN
# 4  5     9    12   0.0

# %% [markdown]
# ## Reading Data into a DataFrame

# %% [markdown]
# #### Read silika CSV

# %%
df2 = pd.read_csv("sakila_example.csv")

df2
# Out:
#                  title                                        description  \
# 0     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 1     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 2     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 3     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 4     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# ..                 ...                                                ...
# 257  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 258  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 259        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 260        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 261        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
#
#         category language        actor_name
# ...

# %%
df2.head()
# Out:
#               title                                        description  \
# 0  ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 1  ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 2  ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 3  ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 4  ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
#
#       category language        actor_name
# 0  Documentary  English  PENELOPE GUINESS
# 1  Documentary  English   CHRISTIAN GABLE
# 2  Documentary  English     LUCILLE TRACY
# 3  Documentary  English       SANDRA PECK
# 4  Documentary  English       JOHNNY CAGE

# %%
df2.tail(10)
# Out:
#                  title                                        description  \
# 252       ATTACKS HATE  A Fast-Paced Panorama of a Technical Writer An...
# 253       ATTACKS HATE  A Fast-Paced Panorama of a Technical Writer An...
# 254       ATTACKS HATE  A Fast-Paced Panorama of a Technical Writer An...
# 255  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 256  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 257  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 258  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 259        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 260        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 261        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
#
#     category language        actor_name
# 252   Sci-Fi  English      MILLA KEITEL
# 253   Sci-Fi  English     GROUCHO DUNST
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        262 non-null    object
#  1   description  262 non-null    object
#  2   category     262 non-null    object
#  3   language     262 non-null    object
#  4   actor_name   262 non-null    object
# dtypes: object(5)
# memory usage: 10.4+ KB

# %% [markdown]
# ### Observations from df2.info()

# %%
# Shows the number of rows and columns in the dataset
# Displays column names and data type 
# Shows how many non-null values exist per column
# Helps null or missing values
# Shows memory usage of the dataset

# %%
df2.describe()
# Out:
#                title                                        description  \
# count            262                                                262
# unique            46                                                 46
# top     ARABIA DOGMA  A Touching Epistle of a Madman And a Mad Cow w...
# freq              12                                                 12
#
#        category language    actor_name
# count       262      262           262
# unique       15        1           145
# top      Horror  English  OPRAH KILMER
# freq         55      262             8

# %% [markdown]
# ### Observations from df2.describe()

# %%
# Mean, min, max values help understand the range of numeric data
# Standard deviation shows how spread out values are

# %% [markdown]
# ## Northwind example csv

# %%
df3 = pd.read_csv("northwind_example.csv")

df3
# Out:
#      OrderID                    ProductName  UnitPrice  Quantity
# 0      10248                 Queso Cabrales       14.0        12
# 1      10248  Singaporean Hokkien Fried Mee        9.8        10
# 2      10248         Mozzarella di Giovanni       34.8         5
# 3      10249          Manjimup Dried Apples       42.4        40
# 4      10249                           Tofu       18.6         9
# ..       ...                            ...        ...       ...
# 495    10435         Mozzarella di Giovanni       27.8        10
# 496    10436         Gnocchi di nonna Alice       30.4        40
# 497    10436       Wimmers gute Semmelkndel       26.6        30
# 498    10436             Rhnbru Klosterbier        6.2        24
# 499    10436                      Spegesild        9.6         5
#
# [500 rows x 4 columns]

# %%
df3.describe() #statistical study of colums
# Out:
#             OrderID   UnitPrice    Quantity
# count    500.000000  500.000000  500.000000
# mean   10341.364000   23.371400   24.330000
# std       54.442663   27.334436   18.069702
# min    10248.000000    2.000000    1.000000
# 25%    10294.000000   10.400000   10.000000
# 50%    10341.000000   15.800000   20.000000
# 75%    10389.000000   27.800000   32.000000
# max    10436.000000  210.800000  120.000000

# %% [markdown]
# ### Observations from df3.describe()

# %%
# Provides summary statistics for numeric columns
# Helps identify ranges, averages, and variability

# %% [markdown]
# ## Coding a DataFrame

# %%
test_data = {
    'ID': [1, 2, 3, 4, 5, 6, 7, 8],
    'Name': ['Alicia', 'Bob', 'Charlie', 'Dominic', 'Eve', 'Frank', 'Grace', 'Heidi'],
    'Age': [25, np.nan, 22, 19, 31, 35, np.nan, 18],
    'City': ['NY', 'LA', 'Chicago', 'Houston', 'Phoenix', 'Boston', 'Austin', 'San Diego'],
    'Score': [85, 92, -1, 65, 78, np.nan, 55, 90]
}

# %%
df4 = pd.DataFrame(test_data) #converts dictionary into a table

df4
# Out:
#    ID     Name   Age       City  Score
# 0   1   Alicia  25.0         NY   85.0
# 1   2      Bob   NaN         LA   92.0
# 2   3  Charlie  22.0    Chicago   -1.0
# 3   4  Dominic  19.0    Houston   65.0
# 4   5      Eve  31.0    Phoenix   78.0
# 5   6    Frank  35.0     Boston    NaN
# 6   7    Grace   NaN     Austin   55.0
# 7   8    Heidi  18.0  San Diego   90.0

# %%
df4.to_csv("test_data.csv", index=False) #index=False prevents adding an extra index column in the CSV
